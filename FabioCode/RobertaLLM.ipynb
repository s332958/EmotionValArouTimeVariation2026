# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip ZipXColab.zip
# Out:
# Archive:  Roberta.zip
#   inflating: utils.py
#    creating: TRAIN_RELEASE_3SEP2025/
#   inflating: TRAIN_RELEASE_3SEP2025/.DS_Store
#   inflating: TRAIN_RELEASE_3SEP2025/train_subtask1.csv
#   inflating: TRAIN_RELEASE_3SEP2025/train_subtask2a.csv
#   inflating: TRAIN_RELEASE_3SEP2025/train_subtask2b.csv
#   inflating: TRAIN_RELEASE_3SEP2025/train_subtask2b_detailed.csv
#   inflating: TRAIN_RELEASE_3SEP2025/train_subtask2b_user_disposition_change.csv
#   inflating: main.py

# %%
# !python main.py
# Out:
# 2025-12-23 11:54:57.100218: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766490897.119630    4941 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766490897.125539    4941 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766490897.140511    4941 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
